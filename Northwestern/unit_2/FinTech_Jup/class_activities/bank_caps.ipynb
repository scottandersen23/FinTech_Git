# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Market Capitalization.

This script showcases the use of Python Dicts to determine the
bank names associated with the corresponding market cap ranges.
"""

# Banks and Market Caps
#-----------------------
# JP Morgan Chase: 327
# Bank of America: 302
# Citigroup: 170
# Wells Fargo: 273
# Goldman Sachs: 87
# Morgan Stanley: 72
# U.S. Bancorp: 83
# TD Bank: 108
# PNC Financial Services: 67
# Capital One: 47
# FNB Corporation: 4
# First Hawaiian Bank: 3
# Ally Financial: 12
# Wachovia: 145
# Republic Bancorp: .97

# @TODO: Initialize a dictionary of banks and market caps (in billions)



bank_caps = { 'JPMorgan': 327, 
            "Bank of America": 302, 
            'Citigroup': 170,
            'Wells Fargo': 273,
            'Goldman Sachs': 87,
            'Morgan Stanley': 72,
            'U.S. Bancorp': 83,
             'TD Bank': 108,
             'PNC Financial Services': 67,
             'Capital One': 47,
             'FNB Corporation': 4,
             'First Hawaiian Bank': 3,
             'Ally Financial': 12,
             'Wachovia': 145,
             'Republic Bancorp': .97}





bank_caps['Citigroup'] = 170



del bank_caps['Wachovia']








# @TODO: Change the market cap for 'Citigroup'


# @TODO: Add a new bank and market cap pair


# @TODO: Remove a bank from the dictionary


# @TODO: Print the modified dictionary
